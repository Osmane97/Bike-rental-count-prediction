# %%
import pandas as pd

# %%
data_day = pd.read_csv(r"D:\VS Code Projects\Datasets\Bike Sharing\data_raw\day.csv")
data_hour = pd.read_csv(r"D:\VS Code Projects\Datasets\Bike Sharing\data_raw\hour.csv")

# %%
data_day.shape
# Out:
# (731, 16)

# %%
data_hour.shape
# Out:
# (17379, 17)

# %%
data_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
data_day.sample(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 183      184  2011-07-03       3   0     7        0        0           0
# 45        46  2011-02-15       1   0     2        0        2           1
# 409      410  2012-02-14       1   1     2        0        2           1
# 369      370  2012-01-05       1   1     1        0        4           1
# 398      399  2012-02-03       1   1     2        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 183           2  0.716667  0.668575  0.682500   0.228858    2282        2367
# 45            1  0.266087  0.254274  0.314348   0.291374     140        1675
# 409           2  0.319167  0.333946  0.508750   0.141179     135        3787
# 369           1  0.265833  0.278412  0.524167   0.129987     140        3132
# 398           1  0.313333  0.309346  0.526667   0.178496     310        3841
#
#       cnt
# 183  4649
# 45   1815
# 409  3922
# 369  3272
# ...

# %%
#Checking Dates data type day dataset
data_day.dtypes['dteday']
# Out:
# dtype('O')

# %%
#Checking Dates data type for hour dataset
data_hour.dtypes['dteday']
# Out:
# dtype('O')

# %%
#Changing "Date" column type to datetime
data_hour['dteday'] = pd.to_datetime(data_hour['dteday'])
data_day['dteday'] = pd.to_datetime(data_day['dteday'])

# %%
data_day.dtypes['dteday']
# Out:
# dtype('<M8[ns]')

# %%
print(data_day['dteday'].dt.year.value_counts())
print(data_hour['dteday'].dt.year.value_counts().unique())
# Out:
# dteday
# 2012    366
# 2011    365
# Name: count, dtype: int64
# [8734 8645]

# %% [markdown]
# #### Avoid Data Leakage
# ##### To prevent information leakage between training and evaluation:
# - **Training set:** All records from the year 2011
# - **Evaluation set (validation):** First three quarters of 2012
# - **Holdout set (test set):** Last quarter of 2012

# %%
# Sort by date (important to avoid shuffling issues)
data_day =data_day.sort_values(by = 'dteday')
data_hour = data_hour.sort_values(by = ['dteday', 'hr'])

# %%
data_hour.head(24)
# Out:
#     instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0         1 2011-01-01       1   0     1   0        0        6           0
# 1         2 2011-01-01       1   0     1   1        0        6           0
# 2         3 2011-01-01       1   0     1   2        0        6           0
# 3         4 2011-01-01       1   0     1   3        0        6           0
# 4         5 2011-01-01       1   0     1   4        0        6           0
# 5         6 2011-01-01       1   0     1   5        0        6           0
# 6         7 2011-01-01       1   0     1   6        0        6           0
# 7         8 2011-01-01       1   0     1   7        0        6           0
# 8         9 2011-01-01       1   0     1   8        0        6           0
# 9        10 2011-01-01       1   0     1   9        0        6           0
# 10       11 2011-01-01       1   0     1  10        0        6           0
# ...

# %%
# Define cutoff dates
cutoff_date = '2012-01-01'
holdout_day =  '2012-10-01'

# %%
# Train: before 2012
train_data_day = data_day[data_day['dteday']< cutoff_date]
#valid: before Q4 /2012
valid_data_day = data_day[(data_day['dteday']>= cutoff_date) & (data_day['dteday']< holdout_day)]
# Test: after Q3 2012
holdout_data_day = data_day[data_day['dteday']>= holdout_day]

# %%
# Train: before 2012
train_data_hour = data_hour[data_hour['dteday']< cutoff_date]
#valid: before Q4 /2012
valid_data_hour = data_hour[(data_hour['dteday']>= cutoff_date) & (data_hour['dteday']< holdout_day)]
#test: after Q3 /2012
holdout_data_hour = data_hour[data_hour['dteday']>= holdout_day]

# %%
holdout_data_hour.head()
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 15211    15212 2012-10-01       4   1    10   0        0        1           1
# 15212    15213 2012-10-01       4   1    10   1        0        1           1
# 15213    15214 2012-10-01       4   1    10   2        0        1           1
# 15214    15215 2012-10-01       4   1    10   3        0        1           1
# 15215    15216 2012-10-01       4   1    10   4        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 15211           1  0.46  0.4545  0.72     0.1045       6          39   45
# 15212           1  0.44  0.4394  0.77     0.0896       5          13   18
# 15213           1  0.46  0.4545  0.72     0.0000       6           6   12
# 15214           1  0.44  0.4394  0.77     0.0000       1           6    7
# 15215           1  0.42  0.4242  0.82     0.1045       0          10   10

# %%
valid_data_day.shape
# Out:
# (274, 16)

# %%
train_data_day.shape
# Out:
# (365, 16)

# %%
train_data_hour.shape
# Out:
# (8645, 17)

# %%
data_hour.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
data_day.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
data_hour.head(24)
# Out:
#     instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0         1 2011-01-01       1   0     1   0        0        6           0
# 1         2 2011-01-01       1   0     1   1        0        6           0
# 2         3 2011-01-01       1   0     1   2        0        6           0
# 3         4 2011-01-01       1   0     1   3        0        6           0
# 4         5 2011-01-01       1   0     1   4        0        6           0
# 5         6 2011-01-01       1   0     1   5        0        6           0
# 6         7 2011-01-01       1   0     1   6        0        6           0
# 7         8 2011-01-01       1   0     1   7        0        6           0
# 8         9 2011-01-01       1   0     1   8        0        6           0
# 9        10 2011-01-01       1   0     1   9        0        6           0
# 10       11 2011-01-01       1   0     1  10        0        6           0
# ...

# %%
# Save dataset splits
train_data_hour.to_csv(r'D:\VS Code Projects\Datasets\Bike Sharing\data_splitted\train_hour.csv', index = False)
valid_data_hour.to_csv(r'D:\VS Code Projects\Datasets\Bike Sharing\data_splitted\valid_hour.csv', index = False)
holdout_data_hour.to_csv(r'D:\VS Code Projects\Datasets\Bike Sharing\data_splitted\holdout_hour.csv', index = False)

train_data_day.to_csv(r'D:\VS Code Projects\Datasets\Bike Sharing\data_splitted\train_day.csv', index = False)
valid_data_day.to_csv(r'D:\VS Code Projects\Datasets\Bike Sharing\data_splitted\valid_day.csv', index = False)
holdout_data_day.to_csv(r'D:\VS Code Projects\Datasets\Bike Sharing\data_splitted\holdout_day.csv', index = False)
